# %% [markdown]
# # Local Mini-Circuit-Cutting

# %%
import numpy as np
from qiskit import transpile
from qiskit_aer import AerSimulator
from qiskit.circuit.random import random_circuit
from qiskit.quantum_info import SparsePauliOp
from circuit_knitting.cutting.automated_cut_finding import (
    find_cuts,
    OptimizationParameters,
    DeviceConstraints,
)
from circuit_knitting.cutting import (
    cut_wires,
    expand_observables,
    partition_problem,
    generate_cutting_experiments,
)
import json
import time

def experiment_with_circuit(num_qubits, depth):
    circuit = random_circuit(num_qubits, depth, max_operands=2, seed=1242)
    
    # Adjust observable strings to match the number of qubits
    observable_strings = ["Z" + "I" * (num_qubits - 1),
                          "I" * (num_qubits // 2) + "Z" + "I" * (num_qubits // 2 - 1),
                          "I" * (num_qubits - 1) + "Z"]
    observable_strings = [obs if len(obs) == num_qubits else "I" * num_qubits for obs in observable_strings]
    observable = SparsePauliOp(observable_strings)

    optimization_settings = OptimizationParameters(seed=111)
    device_constraints = DeviceConstraints(qubits_per_subcircuit=4)

    cut_circuit, metadata = find_cuts(circuit, optimization_settings, device_constraints)
    print(f'Found solution using {len(metadata["cuts"])} cuts with a sampling overhead of {metadata["sampling_overhead"]}.')
    for cut in metadata["cuts"]:
        print(f"{cut[0]} at circuit instruction index {cut[1]}")

    qc_w_ancilla = cut_wires(cut_circuit)
    observables_expanded = expand_observables(observable.paulis, circuit, qc_w_ancilla)

    partitioned_problem = partition_problem(circuit=qc_w_ancilla, observables=observables_expanded)
    subcircuits = partitioned_problem.subcircuits
    subobservables = partitioned_problem.subobservables

    print(f"Sampling overhead: {np.prod([basis.overhead for basis in partitioned_problem.bases])}")

    subexperiments, coefficients = generate_cutting_experiments(circuits=subcircuits, observables=subobservables, num_samples=1000)
    print(f"{len(subexperiments[0]) + len(subexperiments[1])} total subexperiments to run on backend.")

    backend = AerSimulator()
    results = {}

    total_time = 0
    for subexperiment in subexperiments.values():
        for i, circuit in enumerate(subexperiment):
            print(f"Running subcircuit {i}...")
            transpiled_circuit = transpile(circuit, backend)
            subexperiment_start = time.time()
            result = backend.run(transpiled_circuit).result()
            total_time += time.time() - subexperiment_start
            counts = result.get_counts()
            results[i] = counts
            print(f"Subcircuit {i} took {time.time() - subexperiment_start} seconds to run.")

    print("Running original circuit...")
    original_start = time.time()
    original_counts = backend.run(circuit).result().get_counts()
    original_time = time.time() - original_start
    results["original"] = original_counts

    print(f"Original circuit took {original_time} seconds to run.")
    print(f"Cuts took {total_time} seconds to run.")

    with open("results.json", "w") as f:
        json.dump(results, f)

    return results, total_time, original_time

# Example usage with optimized parameters (8 qubits, depth 3, 1000 samples)
results, total_time, original_time = experiment_with_circuit(8, 4)

results, total_time, original_time
# Out:
# Found solution using 2 cuts with a sampling overhead of 14.128980038696172.
# Gate Cut at circuit instruction index 13
# Gate Cut at circuit instruction index 19
# Sampling overhead: 14.128980038696168
# 68 total subexperiments to run on backend.
# Running subcircuit 0...
# Subcircuit 0 took 0.004372119903564453 seconds to run.
# Running subcircuit 1...
# Subcircuit 1 took 0.0012557506561279297 seconds to run.
# Running subcircuit 2...
# Subcircuit 2 took 0.0015749931335449219 seconds to run.
# Running subcircuit 3...
# Subcircuit 3 took 0.0012869834899902344 seconds to run.
# Running subcircuit 4...
# Subcircuit 4 took 0.0011260509490966797 seconds to run.
# Running subcircuit 5...
# Subcircuit 5 took 0.0011637210845947266 seconds to run.
# Running subcircuit 6...
# Subcircuit 6 took 0.001251220703125 seconds to run.
# Running subcircuit 7...
# Subcircuit 7 took 0.0010752677917480469 seconds to run.
# Running subcircuit 8...
# Subcircuit 8 took 0.0011510848999023438 seconds to run.
# Running subcircuit 9...
# Subcircuit 9 took 0.0011818408966064453 seconds to run.
# Running subcircuit 10...
# Subcircuit 10 took 0.0013828277587890625 seconds to run.
# Running subcircuit 11...
# Subcircuit 11 took 0.0012698173522949219 seconds to run.
# Running subcircuit 12...
# Subcircuit 12 took 0.001077890396118164 seconds to run.
# Running subcircuit 13...
# Subcircuit 13 took 0.0011792182922363281 seconds to run.
# Running subcircuit 14...
# Subcircuit 14 took 0.0029058456420898438 seconds to run.
# Running subcircuit 15...
# Subcircuit 15 took 0.0011038780212402344 seconds to run.
# Running subcircuit 16...
# Subcircuit 16 took 0.0010991096496582031 seconds to run.
# Running subcircuit 17...
# Subcircuit 17 took 0.0016160011291503906 seconds to run.
# Running subcircuit 18...
# Subcircuit 18 took 0.0011239051818847656 seconds to run.
# Running subcircuit 19...
# Subcircuit 19 took 0.001110076904296875 seconds to run.
# Running subcircuit 20...
# Subcircuit 20 took 0.0012149810791015625 seconds to run.
# Running subcircuit 21...
# Subcircuit 21 took 0.0011000633239746094 seconds to run.
# Running subcircuit 22...
# Subcircuit 22 took 0.0012407302856445312 seconds to run.
# Running subcircuit 23...
# Subcircuit 23 took 0.0010938644409179688 seconds to run.
# Running subcircuit 24...
# Subcircuit 24 took 0.0011861324310302734 seconds to run.
# Running subcircuit 25...
# Subcircuit 25 took 0.0013210773468017578 seconds to run.
# Running subcircuit 26...
# Subcircuit 26 took 0.0010890960693359375 seconds to run.
# Running subcircuit 27...
# Subcircuit 27 took 0.0012469291687011719 seconds to run.
# Running subcircuit 28...
# Subcircuit 28 took 0.0010769367218017578 seconds to run.
# Running subcircuit 29...
# Subcircuit 29 took 0.0011029243469238281 seconds to run.
# Running subcircuit 30...
# Subcircuit 30 took 0.0021369457244873047 seconds to run.
# Running subcircuit 31...
# Subcircuit 31 took 0.0013298988342285156 seconds to run.
# Running subcircuit 32...
# Subcircuit 32 took 0.0012259483337402344 seconds to run.
# Running subcircuit 33...
# Subcircuit 33 took 0.0013179779052734375 seconds to run.
# Running subcircuit 0...
# Subcircuit 0 took 0.0013949871063232422 seconds to run.
# Running subcircuit 1...
# Subcircuit 1 took 0.0022220611572265625 seconds to run.
# Running subcircuit 2...
# Subcircuit 2 took 0.001138925552368164 seconds to run.
# Running subcircuit 3...
# Subcircuit 3 took 0.0014510154724121094 seconds to run.
# Running subcircuit 4...
# Subcircuit 4 took 0.0012960433959960938 seconds to run.
# Running subcircuit 5...
# Subcircuit 5 took 0.0013589859008789062 seconds to run.
# Running subcircuit 6...
# Subcircuit 6 took 0.0042269229888916016 seconds to run.
# Running subcircuit 7...
# Subcircuit 7 took 0.0035409927368164062 seconds to run.
# Running subcircuit 8...
# Subcircuit 8 took 0.0013871192932128906 seconds to run.
# Running subcircuit 9...
# Subcircuit 9 took 0.0018508434295654297 seconds to run.
# Running subcircuit 10...
# Subcircuit 10 took 0.002119302749633789 seconds to run.
# Running subcircuit 11...
# Subcircuit 11 took 0.0025589466094970703 seconds to run.
# Running subcircuit 12...
# Subcircuit 12 took 0.009794950485229492 seconds to run.
# Running subcircuit 13...
# Subcircuit 13 took 0.0025157928466796875 seconds to run.
# Running subcircuit 14...
# Subcircuit 14 took 0.0030379295349121094 seconds to run.
# Running subcircuit 15...
# Subcircuit 15 took 0.00368499755859375 seconds to run.
# Running subcircuit 16...
# Subcircuit 16 took 0.003704071044921875 seconds to run.
# Running subcircuit 17...
# Subcircuit 17 took 0.002954244613647461 seconds to run.
# Running subcircuit 18...
# Subcircuit 18 took 0.0011920928955078125 seconds to run.
# Running subcircuit 19...
# Subcircuit 19 took 0.0019481182098388672 seconds to run.
# Running subcircuit 20...
# Subcircuit 20 took 0.0013010501861572266 seconds to run.
# Running subcircuit 21...
# Subcircuit 21 took 0.0013949871063232422 seconds to run.
# Running subcircuit 22...
# Subcircuit 22 took 0.0013837814331054688 seconds to run.
# Running subcircuit 23...
# Subcircuit 23 took 0.00128173828125 seconds to run.
# Running subcircuit 24...
# Subcircuit 24 took 0.0012159347534179688 seconds to run.
# Running subcircuit 25...
# Subcircuit 25 took 0.0011861324310302734 seconds to run.
# Running subcircuit 26...
# Subcircuit 26 took 0.0029141902923583984 seconds to run.
# Running subcircuit 27...
# Subcircuit 27 took 0.004910945892333984 seconds to run.
# Running subcircuit 28...
# Subcircuit 28 took 0.0012447834014892578 seconds to run.
# Running subcircuit 29...
# Subcircuit 29 took 0.0013518333435058594 seconds to run.
# Running subcircuit 30...
# Subcircuit 30 took 0.0012531280517578125 seconds to run.
# Running subcircuit 31...
# Subcircuit 31 took 0.0014851093292236328 seconds to run.
# Running subcircuit 32...
# Subcircuit 32 took 0.0024747848510742188 seconds to run.
# Running subcircuit 33...
# Subcircuit 33 took 0.0017521381378173828 seconds to run.
# Running subcircuit 0...
# Subcircuit 0 took 0.0011358261108398438 seconds to run.
# Running subcircuit 1...
# Subcircuit 1 took 0.002315044403076172 seconds to run.
# Running subcircuit 2...
# Subcircuit 2 took 0.003565073013305664 seconds to run.
# Running subcircuit 3...
# Subcircuit 3 took 0.0011479854583740234 seconds to run.
# Running subcircuit 4...
# Subcircuit 4 took 0.0012080669403076172 seconds to run.
# Running subcircuit 5...
# Subcircuit 5 took 0.0010428428649902344 seconds to run.
# Running subcircuit 6...
# Subcircuit 6 took 0.001277923583984375 seconds to run.
# Running subcircuit 7...
# Subcircuit 7 took 0.0009982585906982422 seconds to run.
# Running subcircuit 8...
# Subcircuit 8 took 0.0011577606201171875 seconds to run.
# Running subcircuit 9...
# Subcircuit 9 took 0.0011379718780517578 seconds to run.
# Running subcircuit 10...
# Subcircuit 10 took 0.0028960704803466797 seconds to run.
# Running subcircuit 11...
# Subcircuit 11 took 0.0016770362854003906 seconds to run.
# Running subcircuit 12...
# Subcircuit 12 took 0.0012729167938232422 seconds to run.
# Running subcircuit 13...
# Subcircuit 13 took 0.0011429786682128906 seconds to run.
# Running subcircuit 14...
# Subcircuit 14 took 0.0016450881958007812 seconds to run.
# Running subcircuit 15...
# Subcircuit 15 took 0.0017118453979492188 seconds to run.
# Running subcircuit 16...
# Subcircuit 16 took 0.0012061595916748047 seconds to run.
# Running subcircuit 17...
# Subcircuit 17 took 0.0012319087982177734 seconds to run.
# Running subcircuit 18...
# Subcircuit 18 took 0.0019240379333496094 seconds to run.
# Running subcircuit 19...
# Subcircuit 19 took 0.003008127212524414 seconds to run.
# Running subcircuit 20...
# Subcircuit 20 took 0.0011639595031738281 seconds to run.
# Running subcircuit 21...
# Subcircuit 21 took 0.002207040786743164 seconds to run.
# Running subcircuit 22...
# Subcircuit 22 took 0.0017781257629394531 seconds to run.
# Running subcircuit 23...
# Subcircuit 23 took 0.0031280517578125 seconds to run.
# Running subcircuit 24...
# Subcircuit 24 took 0.0010731220245361328 seconds to run.
# Running subcircuit 25...
# Subcircuit 25 took 0.000978231430053711 seconds to run.
# Running subcircuit 26...
# Subcircuit 26 took 0.0010530948638916016 seconds to run.
# Running subcircuit 27...
# Subcircuit 27 took 0.0013010501861572266 seconds to run.
# Running subcircuit 28...
# Subcircuit 28 took 0.0012621879577636719 seconds to run.
# Running subcircuit 29...
# Subcircuit 29 took 0.0011658668518066406 seconds to run.
# Running subcircuit 30...
# Subcircuit 30 took 0.0033037662506103516 seconds to run.
# Running subcircuit 31...
# Subcircuit 31 took 0.0009670257568359375 seconds to run.
# Running subcircuit 32...
# Subcircuit 32 took 0.0010709762573242188 seconds to run.
# Running subcircuit 33...
# Subcircuit 33 took 0.002743959426879883 seconds to run.
# Running original circuit...
# Original circuit took 0.002792835235595703 seconds to run.
# Cuts took 0.17928004264831543 seconds to run.
# ({0: {'0 0': 524, '0 1': 500},
#   1: {'0 0': 503, '1 1': 521},
#   2: {'1 1': 519, '0 0': 505},
#   3: {'0 1': 523, '0 0': 501},
#   4: {'0 0': 505, '0 1': 519},
#   5: {'0 0': 501, '0 1': 523},
#   6: {'0 1': 467, '0 0': 557},
#   7: {'0 1': 516, '0 0': 508},
#   8: {'0 0': 522, '0 1': 502},
#   9: {'0 1': 530, '0 0': 494},
#   10: {'1 1': 539, '0 0': 485},
#   11: {'0 0': 500, '1 1': 524},
#   12: {'0 0': 529, '0 1': 495},
#   13: {'0 1': 502, '0 0': 522},
#   14: {'0 0': 535, '1 1': 489},
#   15: {'0 0': 513, '1 1': 511},
#   16: {'0 0': 501, '0 1': 523},
#   17: {'0 0': 522, '0 1': 502},
#   18: {'0 0': 529, '1 1': 495},
#   19: {'1 1': 514, '0 0': 510},
#   20: {'0 0': 483, '0 1': 541},
#   21: {'0 0': 515, '0 1': 509},
#   22: {'0 0': 506, '1 1': 518},
#   23: {'1 1': 495, '0 0': 529},
#   24: {'0 0': 480, '0 1': 544},
#   25: {'0 1': 532, '0 0': 492},
#   26: {'0 0': 512, '0 1': 512},
#   27: {'0 0': 524, '0 1': 500},
#   28: {'0 1': 534, '0 0': 490},
#   29: {'0 0': 509, '0 1': 515},
#   30: {'0 0': 540, '1 1': 484},
#   31: {'0 0': 496, '0 1': 528},
#   32: {'0 1': 524, '0 0': 500},
#   33: {'1 1': 510, '0 0': 514},
#   'original': {'0 0': 487, '1 1': 537}},
#  0.17928004264831543,
#  0.002792835235595703)

# %% [markdown]
# # With IBMQ Mini-Circuit-Cutting

# %%
import numpy as np
import json
import time
from qiskit import transpile, QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler, Session
from qiskit.quantum_info import SparsePauliOp
from qiskit.circuit.random import random_circuit
from circuit_knitting.cutting.automated_cut_finding import (
    find_cuts,
    OptimizationParameters,
    DeviceConstraints,
)
from circuit_knitting.cutting import (
    cut_wires,
    expand_observables,
    partition_problem,
    generate_cutting_experiments,
)

def experiment_with_circuit(num_qubits, depth, use_ibmq=False):
    circuit = random_circuit(num_qubits, depth, max_operands=2, seed=1242)
    
    # Adjust observable strings to match the number of qubits
    observable_strings = ["Z" + "I" * (num_qubits - 1),
                          "I" * (num_qubits // 2) + "Z" + "I" * (num_qubits // 2 - 1),
                          "I" * (num_qubits - 1) + "Z"]
    observable_strings = [obs if len(obs) == num_qubits else "I" * num_qubits for obs in observable_strings]
    observable = SparsePauliOp(observable_strings)

    optimization_settings = OptimizationParameters(seed=111)
    device_constraints = DeviceConstraints(qubits_per_subcircuit=7)

    cut_circuit, metadata = find_cuts(circuit, optimization_settings, device_constraints)
    print(f'Found solution using {len(metadata["cuts"])} cuts with a sampling overhead of {metadata["sampling_overhead"]}.')
    for cut in metadata["cuts"]:
        print(f"{cut[0]} at circuit instruction index {cut[1]}")

    qc_w_ancilla = cut_wires(cut_circuit)
    observables_expanded = expand_observables(observable.paulis, circuit, qc_w_ancilla)

    partitioned_problem = partition_problem(circuit=qc_w_ancilla, observables=observables_expanded)
    subcircuits = partitioned_problem.subcircuits
    subobservables = partitioned_problem.subobservables

    print(f"Sampling overhead: {np.prod([basis.overhead for basis in partitioned_problem.bases])}")

    subexperiments, coefficients = generate_cutting_experiments(circuits=subcircuits, observables=subobservables, num_samples=1000)
    print(f"{len(subexperiments[0]) + len(subexperiments[1])} total subexperiments to run on backend.")
    
    print("Subexperiments:", subexperiments)

    results = {}
    total_time = 0

    if use_ibmq:
        # IBM Quantum setup
        service = QiskitRuntimeService(channel="ibm_quantum", token="f4578dfc2792a51df5907e166130b002695c4de4f2c694baa77b060328ac5dec1638d0930e8ebf00927adcfc57c660c7a1d8ce26b2ed7113230f6c23914599bf")
        backend = service.backend("ibm_brisbane")
        
        # Create a session with the ibm_brisbane backend
        session = Session(service=service, backend='ibm_brisbane')
        sampler = Sampler(session=session)
        
        for batch, subcircuits in subexperiments.items():
            transpiled_subcircuits = []
            for subcircuit in subcircuits:
                # Add classical register and measurement
                creg = ClassicalRegister(subcircuit.num_qubits, 'creg')
                subcircuit.add_register(creg)
                for q in range(subcircuit.num_qubits):
                    subcircuit.measure(q, creg[q])
                # Transpile the subcircuit
                transpiled_subcircuit = transpile(subcircuit, backend, optimization_level=1)
                transpiled_subcircuits.append(transpiled_subcircuit)
            
            subexperiment_start = time.time()
            job = sampler.run(transpiled_subcircuits)
            result = job.result()
            total_time += time.time() - subexperiment_start
            
            for i, counts in enumerate(result.quasi_dists):
                results[f"{batch}_{i}"] = counts
            
            print(f"Batch {batch} took {time.time() - subexperiment_start} seconds to run.")

        print("Running original circuit...")
        creg = ClassicalRegister(circuit.num_qubits, 'creg')
        circuit.add_register(creg)
        for q in range(circuit.num_qubits):
            circuit.measure(q, creg[q])
        transpiled_circuit = transpile(circuit, backend, optimization_level=1)
        
        original_start = time.time()
        job = sampler.run(transpiled_circuit, shots=1000)
        result = job.result()
        original_time = time.time() - original_start
        results["original"] = result.quasi_dists[0]

        for subexperiment in subexperiments.values():
            for i, circuit in enumerate(subexperiment):
                print(f"Running subcircuit {i}...")
                transpiled_circuit = transpile(circuit, backend)
                subexperiment_start = time.time()
                result = backend.run(transpiled_circuit).result()
                total_time += time.time() - subexperiment_start
                counts = result.get_counts()
                results[i] = counts
                print(f"Subcircuit {i} took {time.time() - subexperiment_start} seconds to run.")

        print("Running original circuit...")
        original_start = time.time()
        original_counts = backend.run(circuit).result().get_counts()
        original_time = time.time() - original_start
        results["original"] = original_counts

    print(f"Original circuit took {original_time} seconds to run.")
    print(f"Cuts took {total_time} seconds to run.")

    with open("results.json", "w") as f:
        json.dump(results, f)

    return results, total_time, original_time


# For IBM Quantum hardware:
results, total_time, original_time = experiment_with_circuit(8, 4, use_ibmq=True)
# Out:
# Found solution using 1 cuts with a sampling overhead of 1.783275571221539.
# Gate Cut at circuit instruction index 13
# Sampling overhead: 1.783275571221539
# 12 total subexperiments to run on backend.
# Subexperiments: {0: [<qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x319c13dd0>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x16a550190>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x319c13a90>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x319c10cd0>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x319b9e350>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x16a5314d0>], 1: [<qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x16a5cd7d0>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x16a493c10>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x1110f4510>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x16a4662d0>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x16a47c350>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x1111139d0>]}
# /var/folders/w5/qtgfh_kx375_3385y0kbwgy40000gn/T/ipykernel_6724/3653426976.py:62: DeprecationWarning: The Sampler and Estimator V1 primitives have been deprecated as of qiskit-ibm-runtime 0.23.0 and will be removed no sooner than 3 months after the release date. Please use the V2 Primitives. See the `V2 migration guide <https://docs.quantum.ibm.com/api/migration-guides/v2-primitives>`_. for more details
#   sampler = Sampler(session=session)
# Batch 0 took 291.1208908557892 seconds to run.
# Batch 1 took 63.281394958496094 seconds to run.
# Running original circuit...
# Running subcircuit 0...
# /var/folders/w5/qtgfh_kx375_3385y0kbwgy40000gn/T/ipykernel_6724/3653426976.py:104: DeprecationWarning: backend.run() and related sessions methods are deprecated  as of qiskit-ibm-runtime 0.23 and will be removed no sooner than 6 months after the release date. More details can be found in the primitives migration guide https://docs.quantum.ibm.com/api/migration-guides/qiskit-runtime.
#   result = backend.run(transpiled_circuit).result()
# Subcircuit 0 took 98.17586588859558 seconds to run.
# Running subcircuit 1...
# Subcircuit 1 took 27.412906885147095 seconds to run.
# Running subcircuit 2...
# Subcircuit 2 took 20.862608909606934 seconds to run.
# Running subcircuit 3...
# Subcircuit 3 took 28.183209896087646 seconds to run.
# Running subcircuit 4...
# Subcircuit 4 took 35.09509873390198 seconds to run.
# Running subcircuit 5...
# Subcircuit 5 took 20.407121181488037 seconds to run.
# Running subcircuit 0...
# Subcircuit 0 took 39.35172772407532 seconds to run.
# Running subcircuit 1...
# Subcircuit 1 took 21.97625494003296 seconds to run.
# Running subcircuit 2...
# Subcircuit 2 took 20.65148687362671 seconds to run.
# Running subcircuit 3...
# Subcircuit 3 took 24.904088258743286 seconds to run.
# Running subcircuit 4...
# Subcircuit 4 took 32.534209966659546 seconds to run.
# Running subcircuit 5...
# Subcircuit 5 took 19.189459085464478 seconds to run.
# Running original circuit...
# /var/folders/w5/qtgfh_kx375_3385y0kbwgy40000gn/T/ipykernel_6724/3653426976.py:112: DeprecationWarning: backend.run() and related sessions methods are deprecated  as of qiskit-ibm-runtime 0.23 and will be removed no sooner than 6 months after the release date. More details can be found in the primitives migration guide https://docs.quantum.ibm.com/api/migration-guides/qiskit-runtime.
#   original_counts = backend.run(circuit).result().get_counts()
# ---------------------------------------------------------------------------
# RuntimeJobFailureError                    Traceback (most recent call last)
# Cell In[2], line 126
#     122     return results, total_time, original_time
#     125 # For IBM Quantum hardware:
# --> 126 results, total_time, original_time = experiment_with_circuit(8, 4, use_ibmq=True)
#
# Cell In[2], line 112, in experiment_with_circuit(num_qubits, depth, use_ibmq)
#     110 print("Running original circuit...")
#     111 original_start = time.time()
# --> 112 original_counts = backend.run(circuit).result().get_counts()
#     113 original_time = time.time() - original_start
#     114 results["original"] = original_counts
#
# File /opt/miniconda3/envs/iisc-test/lib/python3.11/site-packages/qiskit_ibm_runtime/runtime_job.py:164, in RuntimeJob.result(self, timeout, decoder)
#     162     if self._reason == "RAN TOO LONG":
#     163         raise RuntimeJobMaxTimeoutError(error_message)
# --> 164     raise RuntimeJobFailureError(f"Unable to retrieve job result. {error_message}")
#     165 if self._status is JobStatus.CANCELLED:
#     166     raise RuntimeInvalidStateError(
#     167         "Unable to retrieve result for job {}. " "Job was cancelled.".format(self.job_id())
#     168     )
#
# RuntimeJobFailureError: 'Unable to retrieve job result. Instruction s on qubits (0,) from the 0-th circuit is not supported by the target. -- \\n        Transpile your circuits for the target before submitting a primitive query. For\\n        example, you can use the following code block given an IBMBackend object `backend`\\n        and circuits of type `List[QuantumCircuit]`:\\n            from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager\\n            pm = generate_preset_pass_manager(optimization_level=1, target=backend.target)\\n            isa_circuits = pm.run(circuits)\\n        Then pass `isa_circuits` to the Sampler or Estimator.\\n         -- https://ibm.biz/error_codes#1517'
